# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd 'drive/MyDrive/UOttawa/CSI5180/project'
# Out:
# /content/drive/MyDrive/UOttawa/CSI5180/project

# %%
! pip install transformers
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer
import torch
import numpy as np
from torch.utils.data import Dataset
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.9/dist-packages (4.27.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.7)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)

# %%
import json
from sklearn.model_selection import train_test_split

# %%
class Seq2SeqDataset(Dataset):
    """
    Returns addition problems of up to some number of digits in the inputs. Recall
    that all GPT cares about are sequences of integers, and completing them according to
    patterns in the data. Therefore, we have to somehow encode addition problems
    as a sequence of integers.
    
    The sum of two n-digit numbers gives a third up to (n+1)-digit number. So our
    encoding will simply be the n-digit first number, n-digit second number, 
    and (n+1)-digit result, all simply concatenated together. Because each addition
    problem is so structured, there is no need to bother the model with encoding
    +, =, or other tokens. Each possible sequence has the same length, and simply
    contains the raw digits of the addition problem.
    
    As a few examples, the 2-digit problems:
    - 85 + 50 = 135 becomes the sequence [8, 5, 5, 0, 1, 3, 5]
    - 6 + 39 = 45 becomes the sequence [0, 6, 3, 9, 0, 4, 5]
    etc.
    
    We will also only train GPT on the final (n+1)-digits because the first
    two n-digits are always assumed to be given. So when we give GPT an exam later,
    we will e.g. feed it the sequence [0, 6, 3, 9], which encodes that we'd like
    to add 6 + 39, and hope that the model completes the integer sequence with [0, 4, 5]
    in 3 sequential steps.
    
    fun exercise: does it help if the result is asked to be produced in reverse order?
    """

    def __init__(self, data):
        self.data = data # List[Dict('question', 'SPARQL')]

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        data = self.data[idx] # data: Dicts
        return {"input_ids":tokenizer(data['question'])["input_ids"], "labels":tokenizer(data['SPARQL'])["input_ids"]}

# %%
with open('train.json', 'r') as f:
  train_data = json.load(f)

#with open('test.json', 'r') as f:
#  test_data = json.load(f)

# %%
train_data, test_data, _1, _2 = train_test_split(train_data, [5]*len(train_data), test_size=0.1, random_state=2023)

# %%
model_checkpoint = "hp_v3.4"
model = AutoModelForSeq2SeqLM.from_pretrained(model_checkpoint, max_length=1024)
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# %%
batch_size = 50
model_name = model_checkpoint.split("/")[-1]
args = Seq2SeqTrainingArguments(
    output_dir=f"{model_name}-finetuned",
    overwrite_output_dir = True,
    evaluation_strategy = "epoch",
    logging_strategy = "steps",
    logging_steps = 4,
    #save_strategy = "epoch",
    learning_rate=5e-4,
    gradient_accumulation_steps = 3,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    weight_decay=1e-3,
    save_total_limit=1,
    num_train_epochs=60,
    predict_with_generate=True,
    generation_max_length = 1024,
    push_to_hub=False,
    lr_scheduler_type='linear',
    warmup_steps = 3,
    #load_best_model_at_end=True,
)

data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# %%
trainer = Seq2SeqTrainer(
    model,
    args,
    train_dataset=Seq2SeqDataset(train_data),
    eval_dataset=Seq2SeqDataset(test_data),
    data_collator=data_collator,
    tokenizer=tokenizer,
)

trainer.train()
# Out:
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='120' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [120/120 05:08, Epoch 51/60]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>No log</td>
#       <td>3.231097</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.562800</td>
#       <td>3.046145</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.562800</td>
#       <td>2.150558</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.000100</td>
#       <td>1.414960</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.000100</td>
#       <td>1.202036</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.487200</td>
#       <td>0.800815</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.857700</td>
#       <td>0.673003</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.857700</td>
#       <td>0.611273</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.604500</td>
#       <td>0.433146</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.604500</td>
#       <td>0.456309</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.421100</td>
#       <td>0.411948</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.347400</td>
#       <td>0.332204</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.347400</td>
#       <td>0.339047</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.264100</td>
#       <td>0.341972</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.264100</td>
#       <td>0.304344</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.215200</td>
#       <td>0.249245</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.215200</td>
#       <td>0.298117</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.197800</td>
#       <td>0.317229</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.160000</td>
#       <td>0.292162</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.160000</td>
#       <td>0.282449</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.138500</td>
#       <td>0.245821</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.138500</td>
#       <td>0.218100</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.122100</td>
#       <td>0.236505</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.108400</td>
#       <td>0.228190</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.108400</td>
#       <td>0.210279</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.088000</td>
#       <td>0.248514</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.088000</td>
#       <td>0.224559</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.085900</td>
#       <td>0.224826</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.085900</td>
#       <td>0.236435</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.066400</td>
#       <td>0.214936</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.069200</td>
#       <td>0.247456</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.069200</td>
#       <td>0.239260</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.053000</td>
#       <td>0.202326</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.053000</td>
#       <td>0.208325</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.048600</td>
#       <td>0.233122</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.043700</td>
#       <td>0.218595</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.043700</td>
#       <td>0.220430</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.032400</td>
#       <td>0.228317</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.032400</td>
#       <td>0.234290</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.029300</td>
#       <td>0.222634</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.029300</td>
#       <td>0.220958</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.024100</td>
#       <td>0.203032</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.021900</td>
#       <td>0.200659</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.021900</td>
#       <td>0.203315</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.017300</td>
#       <td>0.207795</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.017300</td>
#       <td>0.210154</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.017000</td>
#       <td>0.210427</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.015900</td>
#       <td>0.211000</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.015900</td>
#       <td>0.211903</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.015200</td>
#       <td>0.211889</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.015200</td>
#       <td>0.211640</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.013100</td>
#       <td>0.211516</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=120, training_loss=0.4376039388900002, metrics={'train_runtime': 311.6461, 'train_samples_per_second': 60.068, 'train_steps_per_second': 0.385, 'total_flos': 332849416273920.0, 'train_loss': 0.4376039388900002, 'epoch': 51.43})

# %% [markdown]
# ### Result

# %% [markdown]
# #### Testing 1

# %% [markdown]
# #### Testing 2

# %%
#@title Default title text
test = Seq2SeqDataset(train_data)
count = 0
for index in range(len(test)):
  device = 'cuda'
  preds = model.generate(input_ids = torch.tensor(test[index]["input_ids"]).to(device).view(1,-1))
  #print(np.array(test[index]["labels"]))
  print("Question:")
  print(tokenizer.decode(np.array(test[index]["input_ids"]))[3:-4])
  print("Prediction:")
  print(tokenizer.decode(np.array(preds.cpu()[0]))[7:-4])
  print("Ground truth:")
  print(tokenizer.decode(np.array(test[index]["labels"]))[3:-4])
  print()
  #count+=1.0*(int(tokenizer.decode(np.array(preds.cpu()[0]))[5:-4]) == int(tokenizer.decode(np.array(test[index]["labels"]))[:-4]))
  #if index%10==0:
    #print(tokenizer.decode(np.array(preds.cpu()[0]))[5:-4],tokenizer.decode(np.array(test[index]["labels"]))[:-4])
count/len(test)
# Out:
# Question:
# Who are the individuals who have held the title 'Minister for Magic'?
# Prediction:
# SELECT?individual WHERE {?individual hp:title hp:Minister_for_magic. }
# Ground truth:
# SELECT?individual WHERE {?individual hp:title hp:Minister_for_magic. }
#
# Question:
# What is the blood status of Cornelius Fudge and Pius Thicknesse?
# Prediction:
# SELECT?individual?blood WHERE {?individual a hp:Individual_ ; hp:blood?blood. FILTER (?individual IN (hp:Cornelius_fudge, hp:Pius_thicknesse)) }
# Ground truth:
# SELECT?individual?blood WHERE {?individual a hp:Individual_ ; hp:blood?blood. FILTER (?individual IN (hp:Cornelius_fudge, hp:Pius_thicknesse)) }
#
# Question:
# Who are the members of the Edgecombe family?
# Prediction:
# SELECT?member WHERE { hp:Edgecombe_family hp:members?member.}
# Ground truth:
# SELECT?member WHERE { hp:Edgecombe_family hp:members?member.}
#
# Question:
# Who are the enemies of the International Confederation of Wizards?
# Prediction:
# SELECT?enemy WHERE { hp:International_confederation_of_wizards hp:enemies?enemy.}
# Ground truth:
# SELECT?enemy WHERE { hp:International_confederation_of_wizards hp:enemies?enemy.}
#
# Question:
# What is the location of London and who are its residents?
# Prediction:
# SELECT?location?resident WHERE { hp:London hp:location?location. OPTIONAL {?location hp:residents?resident.}}
# Ground truth:
# SELECT?location?resident WHERE { hp:London hp:location?location. OPTIONAL {?location hp:residents?resident.}}
#
# Question:
# Which individuals have a boggart that transforms into Tom Riddle?
# Prediction:
# SELECT?individual WHERE {?individual hp:boggart hp:Tom_riddle. }
# Ground truth:
# SELECT?individual WHERE {?individual hp:boggart hp:Tom_riddle. }
#
# Question:
# Which organisations are affiliated with the Hogwarts School of Witchcraft and Wizardry?
# Prediction:
# SELECT DISTINCT?org1?org2 WHERE {?organisation hp:loyalty hp:Hogwarts_school_of_witchcraft_and_wizardry. FILTER (?organisation!= hp:Great_britain)))}
# Ground truth:
# SELECT?organisation WHERE {?organisation hp:loyalty hp:Hogwarts_school_of_witchcraft_and_wizardry. FILTER (?organisation!= hp:Hogwarts_school_of_witchcraft_and_wizardry)}
#
# Question:
# What is the boggart of Cornelius Fudge?
# Prediction:
# SELECT?boggart WHERE { hp:Cornelius_fudge hp:boggarts? boggart.}
# Ground truth:
# SELECT?boggart WHERE { hp:Cornelius_fudge hp:boggart?boggart.}
#
# Question:
# What is the blood status of Pius Thicknesse?
# Prediction:
# SELECT?blood WHERE { hp:Pius_thicknesse hp:blood?blood.}
# Ground truth:
# SELECT?blood WHERE { hp:Pius_thicknesse hp:blood?blood.}
#
# Question:
# Where is the location of Whitehall?
# Prediction:
# SELECT?location WHERE { hp:Whitehall hp:location?location.}
# Ground truth:
# SELECT?location WHERE { hp:Whitehall hp:location?location.}
#
# Question:
# Who is the wife of Marietta Edgecombe's father?
# Prediction:
# SELECT?wife WHERE { hp:Marietta_edgecombes_father hp:wife?wife.}
# Ground truth:
# SELECT?wife WHERE { hp:Marietta_edgecombes_father hp:wife?wife.}
#
# Question:
# Which individuals have loyalty to both the British Ministry of Magic and Hogwarts School of Witchcraft and Wizardry?
# Prediction:
# SELECT?individualName WHERE {?individual hp:loyalty hp:British_ministry_of_magic, hp:Hogwarts_school_ of_witchcraft_and_wizardry.?individual a hp:Individual_.}
# Ground truth:
# SELECT?individual WHERE {?individual hp:loyalty hp:British_ministry_of_magic, hp:Hogwarts_school_of_witchcraft_and_wizardry.}
#
# Question:
# Who are the residents of London?
# Prediction:
# SELECT?resident WHERE { hp:London hp:residents?resident. }
# Ground truth:
# SELECT?resident WHERE { hp:London hp:residents?resident. }
#
# Question:
# What is the job of Millicent Bagnold?
# Prediction:
# SELECT?job WHERE { hp:Millicent_bagnold hp:job?job.}
# Ground truth:
# SELECT?job WHERE { hp:Millicent_bagnold hp:job?job.}
#
# Question:
# Who are the male individuals that have served as Minister for Magic?
# Prediction:
# SELECT?individualName WHERE {?individual hp:gender hp:Male ; hp:job hp:Minister_for_magic ; a hp:IndividualName.}
# Ground truth:
# SELECT?individualName WHERE {?individual hp:gender hp:Male ; hp:job hp:Minister_for_magic ; hp:name?individualName.}
#
# Question:
# What is the gender of Hector Fawley?
# Prediction:
# SELECT?gender WHERE { hp:Hector_fawley hp:gender?gender.}
# Ground truth:
# SELECT?gender WHERE { hp:Hector_fawley hp:gender?gender ; hp:name hp:Hector_fawley.}
#
# Question:
# Which individuals have the loyalty of the Edgecombe family?
# Prediction:
# SELECT?individualName WHERE { hp:Edgecombe_family hp:loyalty?loyalting.?individual hp:name?individualname.}
# Ground truth:
# SELECT?individualName WHERE { hp:Edgecombe_family hp:loyalty?loyalty ; hp:name hp:Edgecombe_family.?individual hp:loyalty?loyalty ; hp:name?individualName.}
#
# Question:
# What is the species of Gellert Grindelwald?
# Prediction:
# SELECT?species WHERE { hp:Gellert_grindelwald hp:species?species.}
# Ground truth:
# SELECT?species WHERE { hp:Gellert_grindelwald hp:species?species ; hp:name hp:Gellert_grindelwald.}
#
# Question:
# Who is the leader of the Ministry of Magic?
# Prediction:
# SELECT?leader WHERE { hp:Ministry_of_magic hp:leader?leader.}
# Ground truth:
# SELECT?leader WHERE { hp:Ministry_of_magic hp:leader?leader.}
#
# Question:
# What is the location of Whitehall?
# Prediction:
# SELECT?location WHERE { hp:Whitehall hp:location?location.}
# Ground truth:
# SELECT?location WHERE { hp:Whitehall hp:location?location. }
#
# Question:
# What is the job of Hermione Granger?
# Prediction:
# SELECT?job WHERE { hp:Hermione_granger hp:job?job. }
# Ground truth:
# SELECT?job WHERE { hp:Hermione_granger hp:job?job. }
#
# Question:
# What is the status of the Edgecombe family?
# Prediction:
# SELECT?status WHERE { hp:Edgecombe_family hp:status?status. }
# Ground truth:
# SELECT?status WHERE { hp:Edgecombe_family hp:status?status. }
#
# Question:
# Who are the members of the Edgecombe family who attended Hogwarts School of Witchcraft and Wizardry and were sorted into Ravenclaw?
# Prediction:
# SELECT DISTINCT?memberName WHERE { hp:Edgecombe_family hp:members?member.?member hp:house hp:Ravenclaw ; hp:name?member_name. }
# Ground truth:
# SELECT DISTINCT?memberName WHERE { hp:Edgecombe_family hp:members?member.?member hp:house hp:Ravenclaw ; hp:name?memberName. }
#
# Question:
# What are the names of all individuals who are affiliated with the British Ministry of Magic, are enemies of Gellert Grindelwald, and have served as Minister for Magic?
# Prediction:
# SELECT?name WHERE {?person hp:affiliation hp:British_ministry_of_magic ; hp:name?name.?person a hp:Individual_. }
# Ground truth:
# SELECT DISTINCT?ministerName WHERE {?minister hp:affiliation hp:British_ministry_of_magic ; hp:name?ministerName.?icw hp:enemies hp:Gellert_grindelwald. FILTER NOT EXISTS {?minister hp:loyalty?loyalty. FILTER (?loyalty!= hp:British_ministry_of_magic)} FILTER NOT EXISTS {?minister hp:enemies hp:Gellert_grindelwald. }}
#
# Question:
# What is the blood status and boggart of Cornelius Fudge?
# Prediction:
# SELECT?blood?boggart WHERE { hp:Cornelius_fudge hp:blood?blood ; hp:enemies hp:Boggart. }
# Ground truth:
# SELECT?bloodStatus?boggart WHERE { hp:Cornelius_fudge hp:blood?bloodStatus ; hp:boggart?boggart. }
#
# Question:
# Who are the known members of the Edgecombe family?
# Prediction:
# SELECT?member WHERE { hp:Edgecombe_family hp:members?member.}
# Ground truth:
# SELECT?member WHERE { hp:Edgecombe_family hp:members?member.}
#
# Question:
# Which organisations is Marietta Edgecombe loyal to?
# Prediction:
# SELECT?individualName WHERE { hp:Edgecombe_family hp:loyalty?individual.?individual hp:name hp:Marietta_edgecombes_father hp:daughter hp:Harry_potter. FILTER(?individualName)}
# Ground truth:
# SELECT?loyalty WHERE { hp:Edgecombe_family hp:loyalty?loyalty. OPTIONAL {?member hp:loyalty?loyalty. FILTER(?member IN (hp:Marietta_edgecombe, hp:Marietta_edgecombes_father, hp:Marietta_edgecombes_mother))}}
#
# Question:
# What is the gender and blood status of Pius Thicknesse?
# Prediction:
# SELECT?gender?bloodstatus WHERE { hp:Pius_thicknesse hp:gender?gender ; hp:blood?bloodStatus.}
# Ground truth:
# SELECT?gender?bloodStatus WHERE { hp:Pius_thicknesse hp:gender?gender ; hp:blood?bloodStatus.}
#
# Question:
# What is the job title of Hermione Granger and which organisations is she loyal to?
# Prediction:
# SELECT?jobtitle?loyalty WHERE { hp:Hermione_granger hp:title?jobTitle ; hp:individual_.?individual a hp:Individual_. }
# Ground truth:
# SELECT?jobTitle?loyalty WHERE { hp:Hermione_granger hp:title?jobTitle ; hp:loyalty?loyalty. }
#
# Question:
# Who is Cornelius Fudge?
# Prediction:
# SELECT?individual WHERE { hp:Cornelius_fudge rdf:type hp:Individual_. }
# Ground truth:
# SELECT?individual WHERE { hp:Cornelius_fudge rdf:type hp:Individual_.?individual rdf:type hp:Individual_. FILTER(?individual = hp:Cornelius_fudge)}
#
# Question:
# What is the nationality of Cornelius Fudge?
# Prediction:
# SELECT?nationality WHERE { hp:Cornelius_fudge hp:nationality?nationalization. }
# Ground truth:
# SELECT?nationality WHERE { hp:Cornelius_fudge hp:nationality?nationality. }
#
# Question:
# Who are the ministers for magic that have the same title as Hector Fawley?
# Prediction:
# SELECT?minister WHERE { hp:Hector_fawley hp:title?title. FILTER (?minister!= hp:Great_britain)))}
# Ground truth:
# SELECT?minister WHERE { hp:Hector_fawley hp:title?title.?minister hp:title?title. FILTER(?minister!= hp:Hector_fawley) }
#
# Question:
# Who has Tom Riddle as a boggart?
# Prediction:
# SELECT?individual WHERE {?individual hp:boggart hp:Tom_riddle. }
# Ground truth:
# SELECT?individual WHERE {?individual hp:boggart hp:Tom_riddle. }
#
# Question:
# What is the affiliation of the Ministry of Magic and who is its leader?
# Prediction:
# SELECT?affiliation?leader WHERE { hp:Ministry_of_magic hp:affiliation ; hp:leader?leader.}
# Ground truth:
# SELECT?affiliation?leader WHERE { hp:Ministry_of_magic hp:affiliation?affiliation. hp:Ministry_of_magic hp:leader?leader.}
#
# Question:
# Who are the members of the Edgecombe family and what is their house?
# Prediction:
# SELECT?member?house WHERE { hp:Edgecombe_family hp:members?member.?member hp:house?house.}
# Ground truth:
# SELECT?member?house WHERE { hp:Edgecombe_family hp:members?member.?member hp:house?house.}
#
# Question:
# Who was the Minister for Magic before Cornelius Fudge?
# Prediction:
# SELECT?minister WHERE {minister hp:title hp:Minister_for_magic ; hp:loyalty hp:British_ministry_of_magic; hp:species hp:Human. FILTER (?minister!= hp:Cornelius_fudge)}
# Ground truth:
# SELECT?minister WHERE {?minister hp:title hp:Minister_for_magic ; hp:job hp:Minister_for_magic ; hp:loyalty hp:British_ministry_of_magic ; hp:species hp:Human. FILTER (?minister!= hp:Cornelius_fudge)}
#
# Question:
# Which individuals have served as Minister for Magic and are associated with Hogwarts School of Witchcraft and Wizardry?
# Prediction:
# SELECT DISTINCT?minister WHERE {?minminister hp:title hp:Minister_for_magic ; hp:loyalty hp:Hogwarts_school_of_witchcraft_and_wizardry.}
# Ground truth:
# SELECT?minister WHERE {?minister hp:title hp:Minister_for_magic ; hp:job hp:Minister_for_magic ; hp:loyalty hp:British_ministry_of_magic, hp:Hogwarts_school_of_witchcraft_and_wizardry ; hp:species hp:Human.}
#
# Question:
# Who is/was a member of the Edgecombe family?
# Prediction:
# SELECT?member WHERE { hp:Edgecombe_family hp:members?member.}
# Ground truth:
# SELECT?member WHERE { hp:Edgecombe_family hp:members?member.}
#
# Question:
# What is the location of the Whitehall building?
# Prediction:
# SELECT?location WHERE { hp:Whitehall hp:location?location. }
# Ground truth:
# SELECT?location WHERE { hp:Whitehall hp:location?location. }
#
# Question:
# Which organizations are enemies of the International Confederation of Wizards?
# Prediction:
# SELECT?enemy WHERE { hp:International_confederation_of_wizards hp:enemies?enemy.}
# Ground truth:
# SELECT?enemy WHERE { hp:International_confederation_of_wizards hp:enemies?enemy.}
#
# Question:
# What is the name of the organization associated with Hermione Granger?
# Prediction:
# SELECT?organization WHERE { hp:Hermione_granger hp:loyalty?organisation. FILTER (?organization!= hp:British_ministry_of_magic)}
# Ground truth:
# SELECT?organization WHERE { hp:Hermione_granger hp:loyalty?organization. FILTER (?organization!= hp:British_ministry_of_magic)}
#
# Question:
# What is Cornelius Fudge's gender?
# Prediction:
# SELECT?gender WHERE { hp:Cornelius_fudge hp:gender?gender. }
# Ground truth:
# SELECT?gender WHERE { hp:Cornelius_fudge hp:gender?gender. }
#
# Question:
# What are the names and blood statuses of all the individuals who have been Ministers for Magic?
# Prediction:
# SELECT?name?blood_status WHERE {?minister a hp:Individual_; hp:title hp:Minister_for_magic ; hp:name?name ; blood_status. }
# Ground truth:
# SELECT?name?blood_status WHERE {?minister a hp:Individual_ ; hp:title hp:Minister_for_magic ; hp:name?name ; hp:blood?blood_status. }
#
# Question:
# Which organisations have affiliations with both the British Ministry of Magic and Hogwarts School of Witchcraft and Wizardry?
# Prediction:
# SELECT?org (CONTAINS(str(?organisation), hp:Hogwarts_school_of_witchcraft_and_wizardry)}
# Ground truth:
# SELECT?org_name WHERE {?org a hp:Organisation_ ; hp:affiliation hp:British_ministry_of_magic ; hp:affiliation hp:Hogwarts_school_of_witchcraft_and_wizardry ; hp:name?org_name.}
#
# Question:
# Which individuals have the same blood status as Pius Thicknesse and are affiliated with either the British Ministry of Magic or the Death Eaters?
# Prediction:
# SELECT?name WHERE {?individual hp:blood?blood_status ; hp:loyalty hp:British_ministry_of_magic, hp:Death_eaters ; a hp:Individual_.?individual IN (hp:Pius_thicknesse)) }
# Ground truth:
# SELECT?name WHERE {?individual a hp:Individual_ ; hp:blood?blood_status ; hp:loyalty hp:British_ministry_of_magic, hp:Death_eaters ; hp:name?name. { SELECT?blood_status WHERE { hp:Pius_thicknesse hp:blood?blood_status.}}}
#
# Question:
# What are the blood statuses of individuals who have been Minister for Magic?
# Prediction:
# SELECT DISTINCT?blood WHERE {?person hp:title hp:Minister_for_magic ; hp:name?blood. }
# Ground truth:
# SELECT?name?blood WHERE {?person hp:title hp:Minister_for_magic ; hp:name?name ; hp:blood?blood. }
#
# Question:
# What is the blood status and house of Marietta Edgecombe?
# Prediction:
# SELECT?blood?house WHERE { hp:Marietta_edgecombe hp:blood?blood ; hp:house?house. }
# Ground truth:
# SELECT?blood?house WHERE { hp:Marietta_edgecombe hp:blood?blood ; hp:house?house. }
#
# Question:
# Who are the individuals who have loyalty to both the British Ministry of Magic and Hogwarts School of Witchcraft and Wizardry?
# Prediction:
# SELECT?name  WHERE {?person hp:loyalty hp:British_ministry_of_magic, hp:Hogwarts_school_ of_witchcraft_and_wizardry ; hp:name?name.}
# Ground truth:
# SELECT?name WHERE {?person hp:loyalty hp:British_ministry_of_magic, hp:Hogwarts_school_of_witchcraft_and_wizardry ; hp:name?name.}
#
# Question:
# Who are the individuals who have loyalty to the British Ministry of Magic and are also associated with the Death Eaters?
# Prediction:
# SELECT?name WHERE {?person hp:loyalty hp:British_ministry_of_magic, hp:Death_eaters ; hp:name?name.}
# Ground truth:
# SELECT?name WHERE {?person hp:loyalty hp:British_ministry_of_magic, hp:Death_eaters ; hp:name?name.}
#
# Question:
# Who were the individuals who were loyal to both the British Ministry of Magic and Hogwarts School of Witchcraft and Wizardry?
# Prediction:
# SELECT DISTINCT?individualName  WHERE {?individual hp:loyalty hp:British_ministry_of_magic, hp:Hogwarts_school_of hp:witchcraft_and_wizardry.?person a hp:Individual_. }
# Ground truth:
# SELECT?individualName  WHERE {?individual hp:loyalty hp:British_ministry_of_magic, hp:Hogwarts_school_of_witchcraft_and_wizardry.?individual hp:name?individualName.}
#
# Question:
# Who were the enemies of the International Confederation of Wizards?
# Prediction:
# SELECT?enemy WHERE { hp:International_confederation_of_wizards hp:enemies?enemy.}
# Ground truth:
# SELECT?enemyName  WHERE { hp:International_confederation_of_wizards hp:enemies?enemy.?enemy hp:name?enemyName.}
#
# Question:
# Who were the individuals who had the job of Minister for Magic and were Half-blood or Pure-blood?
# Prediction:
# SELECT?individualName WHERE {?individual hp:job hp:Minister_for_magic ; hp:blood hp:Half_blood, hp:Pure_blood ; a hp:IndividualName. }
# Ground truth:
# SELECT?individualName WHERE {?individual hp:job hp:Minister_for_magic.?individual hp:blood hp:Half_blood, hp:Pure_blood.?individual hp:name?individualName. }
#
# Question:
# Who were the individuals who had a Non-corporeal patronus?
# Prediction:
# SELECT?individualName WHERE {?individual hp:patronus hp:Non_corporeal.?individualhp:name?individualname. }
# Ground truth:
# SELECT?individualName WHERE {?individual hp:patronus hp:Non_corporeal.?individual hp:name?individualName. }
#
# Question:
# Who were the individuals who were born in Great Britain and had the job of Minister for Magic?
# Prediction:
# SELECT?individualName WHERE {?individual hp:born hp:Great_britain.?individual a hp:Individual_ ; hp:job hp:Minister_for_magic. }
# Ground truth:
# SELECT?individualName WHERE {?individual hp:born hp:Great_britain.?individual hp:job hp:Minister_for_magic.?individual hp:name?individualName. }
#
# Question:
# Who were the individuals who had Tom Riddle as their boggart?
# Prediction:
# SELECT?individualName WHERE {?individual hp:boggart hp:Tom_riddle.?individual a hp:IndividualName.}
# Ground truth:
# SELECT?individualName WHERE {?individual hp:boggart hp:Tom_riddle.?individual hp:name?individualName.}
#
# Question:
# What are the names of all individuals who have served as Minister for Magic?
# Prediction:
# SELECT?name WHERE {?minister hp:title hp:Minister_for_magic ; hp:name?name.}
# Ground truth:
# SELECT?name WHERE {?minister hp:title hp:Minister_for_magic.?minister hp:name?name. }
#
# Question:
# Which individual's boggart is Tom Riddle?
# Prediction:
# SELECT?name WHERE {?person hp:boggart hp:Tom_riddle.?individual hp:name?name. }
# Ground truth:
# SELECT?name WHERE {?individual hp:boggart hp:Tom_riddle.?individual hp:name?name. }
#
# Question:
# Who are the individuals that belong to the Edgecombe family?
# Prediction:
# SELECT?member WHERE { hp:Edgecombe_family hp:members?member.}
# Ground truth:
# SELECT?member WHERE { hp:Edgecombe_family hp:members?member.}
#
# Question:
# What are the names of all the enemies of the International Confederation of Wizards?
# Prediction:
# SELECT?name WHERE { hp:International_confederation_of_wizards hp:enemies?enemy.?enemy hp:name?name. }
# Ground truth:
# SELECT?name WHERE { hp:International_confederation_of_wizards hp:enemies?enemy.?enemy hp:name?name. }
#
# Question:
# Who are the individuals that have served as Minister for Magic and are affiliated with Hogwarts School of Witchcraft and Wizardry?
# Prediction:
# SELECT?name WHERE {?minister hp:title hp:Minister_for_magic ; hp:name?name ;hp:loyalty hp:Hogwarts_school_of_witchcraft_and_wizardry.}
# Ground truth:
# SELECT?name WHERE {?minister hp:title hp:Minister_for_magic.?minister hp:name?name.?minister hp:loyalty hp:Hogwarts_school_of_witchcraft_and_wizardry.}
#
# Question:
# What are the genders of individuals who are affiliated with the British Ministry of Magic?
# Prediction:
# SELECT DISTINCT?gender WHERE {?individual hp:loyalty hp:British_ministry_of_magic ; hp:gender?gender. }
# Ground truth:
# SELECT DISTINCT?gender WHERE {?individual hp:loyalty hp:British_ministry_of_magic.?individual hp:gender?gender. }
#
# Question:
# Who are the individuals that have served as Minister for Magic and have a non-corporeal patronus?
# Prediction:
# SELECT?name WHERE {?minister hp:title hp:Minister_for_magic ; hp:patronus hp:Non_corporeal.}
# Ground truth:
# SELECT?name WHERE {?minister hp:title hp:Minister_for_magic.?minister hp:patronus hp:Non_corporeal.?minister hp:name?name. }
#
# Question:
# Who are the members of the Edgecombe family and what is their status?
# Prediction:
# SELECT?member?status WHERE { hp:Edgecombe_family hp:members?member ; hp:status?status.}
# Ground truth:
# SELECT?name?member?status WHERE { hp:Edgecombe_family hp:name?name ; hp:members?member ; hp:status?status.}
#
# Question:
# What is the job of Cornelius Fudge and what is his boggart?
# Prediction:
# SELECT?job?boggart WHERE { hp:Cornelius_fudge hp:job?job ; hp:boggarts?bgoggart.}
# Ground truth:
# SELECT?job?boggart WHERE { hp:Cornelius_fudge hp:job?job ; hp:boggart?boggart.}
#
# Question:
# What is the location of Whitehall and who are its affiliations?
# Prediction:
# SELECT?name?location?affiliation WHERE { hp:Whitehall hp:name?name ; hp:location?location.}
# Ground truth:
# SELECT?name?location?affiliation WHERE { hp:Whitehall hp:name?name ; hp:location?location ; hp:affiliation?affiliation.}
#
# Question:
# Which organizations have the enemies 'Death Eaters', 'Order of the Phoenix', and 'Tom Riddle'?
# Prediction:
# SELECT?org (COUNT(?phoenix) AS?enemyCount) WHERE {?org hp:enemies hp:Death_eaters, hp:Order_of_the_phoenix, 'Tom_riddle.}
# Ground truth:
# SELECT?orgName WHERE {?org a hp:Organisation_ ; hp:name?orgName ; hp:enemies hp:Death_eaters, hp:Order_of_the_phoenix, hp:Tom_riddle.}
#
# Question:
# What are the headquarters of the organizations with the intention of'reverting the consequences of major magical mishaps'?
# Prediction:
# SELECT?orgName?headquarters WHERE {?org1 hp:intentions hp:Reverting_the_consequences_of_major_magical_mishaps.}
# Ground truth:
# SELECT?orgName?headquarters WHERE {?org a hp:Organisation_ ; hp:name?orgName ; hp:intentions hp:Reverting_the_consequences_of_major_magical_mishaps ; hp:headquarters?headquarters.}
#
# Question:
# Who were the male advisors to the Minister for Magic?
# Prediction:
# SELECT?advisor WHERE { hp:Advisor_to_the_minister_for_magic hp:gender?gender.}
# Ground truth:
# SELECT?advisor WHERE {?advisor hp:gender hp:Male.?advisor hp:job hp:Advisor_to_the_minister_for_magic.}
#
# Question:
# What are the affiliations and intentions of the Department of Magical Accidents and Catastrophes?
# Prediction:
# SELECT?affiliation?intention WHERE { hp:Department_of_magical_accidents_and_catastrophes hp:affiliation ; hp:intentions?intention.}
# Ground truth:
# SELECT?affiliation?intention WHERE { hp:Department_of_magical_accidents_and_catastrophes hp:affiliation?affiliation. hp:Department_of_magical_accidents_and_catastrophes hp:intentions?intention.}
#
# Question:
# Who are the individuals with the loyalty to the British Ministry of Magic, the Order of the Phoenix, and Hogwarts School of Witchcraft and Wizardry?
# Prediction:
# SELECT?individual WHERE {?individual hp:loyalty hp:British_ministry_of_magic ; hp:name?individualName.}
# Ground truth:
# SELECT?individual WHERE {?individual hp:loyalty hp:British_ministry_of_magic.?individual hp:loyalty hp:Order_of_the_phoenix.?individual hp:loyalty hp:Hogwarts_school_of_witchcraft_and_wizardry.}
#
# Question:
# Which organisations have enemies in common with the Department of Magical Accidents and Catastrophes?
# Prediction:
# SELECT DISTINCT?org1?org2 WHERE { hp:Department_of_magical_accidents_and_catastrophes hp:enemies?enemy.?org 1 hp:loyalty?enemies. FILTER (?org2!= hp:Wizengamot) }
# Ground truth:
# SELECT DISTINCT?org1?org2 WHERE { hp:Department_of_magical_accidents_and_catastrophes hp:enemies?enemy.?org1 hp:enemies?enemy.?org2 hp:enemies?enemy. FILTER(?org1!=?org2) }
#
# Question:
# Who are the individuals with the title of Chief Warlock and their gender?
# Prediction:
# SELECT?individualName?gender WHERE {?individual hp:job hp:Chief_warlock ; hp:title hp:chief_lock, hp:Wizengamot.?individual a hp:IndividualName.}
# Ground truth:
# SELECT?name?gender WHERE {?individual hp:job hp:Chief_warlock ; hp:title hp:Chief_warlock.?individual hp:name?name.?individual hp:gender?gender.}
#
# Question:
# What are the locations of the Minister for Magic's office and the British Ministry of Magic headquarters?
# Prediction:
# SELECT?location?headquarters WHERE { hp:Minister_for_magics_office hp:location?location ; hp:affiliation hp:British_ministry_of_magic_headquarters.}
# Ground truth:
# SELECT?office_location?headquarters_location WHERE { hp:Minister_for_magics_office hp:location?office_location. hp:British_ministry_of_magic_headquarters hp:location?headquarters_location.}
#
# Question:
# Who are the half-bloods?
# Prediction:
# SELECT?individual WHERE {?individual hp:blood hp:Half_blood.}
# Ground truth:
# SELECT?individual WHERE {?individual hp:blood hp:Half_blood.}
#
# Question:
# What are the names of the organisations with the colour codes #9966cc and #C9a0dc?
# Prediction:
# SELECT?name WHERE {?org a hp:Individual_ ; hp:bgcolor hp:9966cc, hp:C9a0dc.?org hp:name?name. }
# Ground truth:
# SELECT?name WHERE {?org hp:bgcolor hp:9966cc, hp:C9a0dc.?org hp:name?name. }
#
# Question:
# Who are the individuals with Hermione Granger's job and title?
# Prediction:
# SELECT?individual WHERE {?individual hp:job hp:Department_of_magical_law_enforcement, hp:Minister_for_magic ; hp:title?title. }
# Ground truth:
# SELECT?individual WHERE {?individual hp:job hp:Department_of_magical_law_enforcement, hp:Minister_for_magic.?individual hp:title hp:Department_of_magical_law_enforcement, hp:Minister_for_magic. }
#
# Question:
# What is the affiliation of the Educational Office organization?
# Prediction:
# SELECT?affiliation WHERE {hp:Educational_office hp:affiliation?affiliation.}
# Ground truth:
# SELECT?affiliation WHERE {hp:Educational_office hp:affiliation?affiliation.}
#
# Question:
# What is the source URL for the Pure-blood page?
# Prediction:
# SELECT?sourceUrl WHERE {hp:Pure_blood hp:source_url?sourceurl.}
# Ground truth:
# SELECT?source_url WHERE {hp:Pure_blood hp:source_url?source_url.}
#
# Question:
# What is the name of the organization that deals with magical accidents and catastrophes?
# Prediction:
# SELECT?name WHERE {?org a hp:Organisation_ ; hp:name?name ;hp:intentions hp:Reverting_the_consequences_of_major_magical_mishaps.}
# Ground truth:
# SELECT?name WHERE {?org a hp:Organisation_ ; hp:name?name ; hp:intentions hp:Reverting_the_consequences_of_major_magical_mishaps.}
#
# Question:
# Who is the Chief Warlock of the Wizengamot in 1544?
# Prediction:
# SELECT?name WHERE {hp:Chief_warlock_of_the_wizengamot_in_1544 hp:name?name.}
# Ground truth:
# SELECT?name WHERE {hp:Chief_warlock_of_the_wizengamot_in_1544 hp:name?name.}
#
# Question:
# What is the affiliation of the Improper Use of Magic Office organization?
# Prediction:
# SELECT?affiliation WHERE {hp:Improper_use_of_magic_office hp:affiliation?affiliator.}
# Ground truth:
# SELECT?affiliation WHERE {hp:Improper_use_of_magic_office hp:affiliation?affiliation.}
#
# Question:
# What is the name of the wand that belongs to Cornelius Fudge?
# Prediction:
# SELECT?name WHERE {hp:Cornelius_fudges_wand hp:name?name.}
# Ground truth:
# SELECT?name WHERE {hp:Cornelius_fudges_wand hp:name?name.}
#
# Question:
# What is the name of the organization that oversees the wizarding schools?
# Prediction:
# SELECT?name WHERE {hp:Educational_office hp:name?name.}
# Ground truth:
# SELECT?name WHERE {hp:Educational_office hp:name?name.}
#
# Question:
# What is the name of the organization that the Minister for Magic's office is affiliated with?
# Prediction:
# SELECT?name WHERE { hp:Minister_for_magics_office hp:affiliation?affiliation.}
# Ground truth:
# SELECT?affiliation WHERE { hp:Minister_for_magics_office hp:affiliation?affiliation.}
#
# Question:
# What is the name of the organization led by the International Confederation of Wizards and affiliated with Wizardkind?
# Prediction:
# SELECT?name WHERE { hp:Educational_office hp:name?name ; hp:leader hp:International_confederation_of_wizards.}
# Ground truth:
# SELECT?organizationName WHERE { hp:Educational_office hp:name?organizationName ; hp:leader hp:International_confederation_of_wizards ; hp:affiliation hp:Wizardkind.}
#
# Question:
# Which organization is dedicated to reverting the consequences of major magical mishaps and headquartered in the British Ministry of Magic?
# Prediction:
# SELECT?organizationName WHERE { hp:Department_of_magical_accidents_and_catastrophes hp:name?organisationName ; hp:headquarters hp:British_ministry_for_magic.}
# Ground truth:
# SELECT?organizationName WHERE { hp:Department_of_magical_accidents_and_catastrophes hp:name?organizationName ; hp:headquarters hp:British_ministry_of_magic ; hp:intentions hp:Reverting_the_consequences_of_major_magical_mishaps.}
#
# Question:
# Who is the current Minister for Magic and what is the name of their office?
# Prediction:
# SELECT?ministerName?officeName WHERE { hp:Minister_for_magics_office hp:name?office_name.?minminister hp:job hp:Advisor_to_magic.}
# Ground truth:
# SELECT?ministerName?officeName WHERE { hp:Minister_for_magics_office hp:name?officeName.?minister hp:job hp:Minister_for_magic ; hp:name?ministerName.}
#
# Question:
# Which organization is responsible for reversing the consequences of major magical mishaps?
# Prediction:
# SELECT?orgName  WHERE {  hp:Department_of_magical_accidents_and_catastrophes hp:name?officeName.}
# Ground truth:
# SELECT?orgName  WHERE {  hp:Department_of_magical_accidents_and_catastrophes hp:name?orgName ; hp:intentions hp:Reverting_the_consequences_of_major_magical_mishaps.}
#
# Question:
# Who was the Chief Warlock of the Wizengamot in 1544?
# Prediction:
# SELECT?name WHERE {hp:Chief_warlock_of_the_wizengamot_in_1544 hp:name?name.}
# Ground truth:
# SELECT?chief_warlock_name WHERE { hp:Chief_warlock_of_the_wizengamot_in_1544 hp:name?chief_warlock_name.}
#
# Question:
# Who owned Cornelius Fudge's wand?
# Prediction:
# SELECT?wand_owner WHERE { hp:Cornelius_fudges_wand hp:owners?owner.}
# Ground truth:
# SELECT?wand_owner WHERE { hp:Cornelius_fudges_wand hp:owners?wand_owner.}
#
# Question:
# Which Hogwarts house does Hermione Granger belong to?
# Prediction:
# SELECT?house WHERE { hp:Hermione_granger hp:house?house.}
# Ground truth:
# SELECT?hogwarts_house WHERE { hp:Hermione_granger hp:house?hogwarts_house.}
#
# Question:
# Which organizations are enemies of the Improper Use of Magic Office?
# Prediction:
# SELECT?enemy_organization WHERE { hp:Improper_use_of_magic_office hp:enemies?enemy.}
# Ground truth:
# SELECT?enemy_organization WHERE { hp:Improper_use_of_magic_office hp:enemies?enemy_organization.}
#
# Question:
# What is the intention of the Department of Magical Accidents and Catastrophes?
# Prediction:
# SELECT?intention WHERE { hp:Department_of_magical_accidents_and_catastrophes hp:intentions?intention.}
# Ground truth:
# SELECT?intention WHERE { hp:Department_of_magical_accidents_and_catastrophes hp:intentions?intention.}
#
# Question:
# What is the loyalty of Peeves?
# Prediction:
# SELECT?individual WHERE { hp:Peeves hp:loyalty?loyalry ; hp:name Peeves.}
# Ground truth:
# SELECT?loyalty WHERE { hp:Peeves hp:loyalty?loyalty.}
#
# Question:
# What is the name of the office of the head of the British Ministry of Magic and where is it located?
# Prediction:
# SELECT?name?location WHERE { hp:Minister_for_magics_office hp:name?name ; hp:location?location.}
# Ground truth:
# SELECT?name?location WHERE { hp:Minister_for_magics_office hp:name?name ; hp:location?location.}
#
# Question:
# Which organizations are affiliated with the International Confederation of Wizards?
# Prediction:
# SELECT?name WHERE {?organization hp:name?name ; hp:affiliation hp:International_confederation_of_wizards.}
# Ground truth:
# SELECT?name WHERE {?organization hp:name?name ; hp:affiliation hp:International_confederation_of_wizards.}
#
# Question:
# What is the job of Hermione Granger and what are her loyalties?
# Prediction:
# SELECT?job?loyalty WHERE { hp:Hermione_granger hp:job?job ; loyalty.}
# Ground truth:
# SELECT?job?loyalty WHERE { hp:Hermione_granger hp:job?job ; hp:loyalty?loyalty.}
#
# Question:
# What is the wand made by Cornelius Fudge in 1993?
# Prediction:
# SELECT?name WHERE {hp:Cornelius_fudges_wand hp:name?name.}
# Ground truth:
# SELECT?wand_name WHERE { hp:Cornelius_fudges_wand hp:name?wand_name.}
#
# Question:
# Who are the individuals associated with the Hufflepuff house?
# Prediction:
# SELECT?individual WHERE {?individual hp:house hp:Hufflepuff.}
# Ground truth:
# SELECT?individual WHERE {?individual hp:house hp:Hufflepuff.}
#
# Question:
# What Hogwarts house does Hermione Granger belong to and what is her current job title?
# Prediction:
# SELECT?house?job WHERE { hp:Hermione_granger hp:house?house ; hp:title?job.}
# Ground truth:
# SELECT?house?job WHERE { hp:Hermione_granger hp:house?house ; hp:title?job.}
#
# Question:
# Which organization has the most enemies?
# Prediction:
# SELECT?org (COUNT(?enemy) AS?enemyCount) WHERE {?org a hp:Organisation_ ; hp:enemies?enemy. } GROUP BY?org ORDER BY DESC(?org1!=?org2) LIMIT 1
# Ground truth:
# SELECT?org (COUNT(?enemy) AS?enemyCount) WHERE {?org hp:enemies?enemy. } GROUP BY?org ORDER BY DESC(?enemyCount) LIMIT 1
#
# Question:
# Which Hogwarts house has the most individuals affiliated with it and what are their names?
# Prediction:
# SELECT?house (GROUP_CONCAT(?name; separator=", ") AS?names) WHERE {?individual hp:house?house ; hp:name?name. } GROUP BY?house ORDER BY DESC(COUNT(?individual)) LIMIT 1
# Ground truth:
# SELECT?house (GROUP_CONCAT(?name; separator=", ") AS?names) WHERE {?individual hp:house?house ; hp:name?name. } GROUP BY?house ORDER BY DESC(COUNT(?individual)) LIMIT 1
#
# Question:
# Which organizations have the intention of reverting the consequences of major magical mishaps and are enemies of both the Death Eaters and the Order of the Phoenix?
# Prediction:
# SELECT?organization WHERE {?organization hp:intentions hp:Reverting_the_consequences_of_major_magical_mishaps. }
# Ground truth:
# SELECT?organization WHERE {?organization hp:intentions hp:Reverting_the_consequences_of_major_magical_mishaps.?organization hp:enemies hp:Death_eaters, hp:Order_of_the_phoenix.}
#
# Question:
# Who are the individuals who have held the job of Minister for Magic and were also members of Gryffindor house at Hogwarts School of Witchcraft and Wizardry?
# Prediction:
# SELECT?individual WHERE {?individual hp:job hp:Minister_for_magic. }
# Ground truth:
# SELECT?individual WHERE {?individual hp:job hp:Minister_for_magic.?individual hp:house hp:Gryffindor. }
#
# Question:
# Who is the chief warlock of the Wizengamot and what is their gender?
# Prediction:
# SELECT?name?gender WHERE { hp:Chief_warlock_of_the_wizengamot_in_1544 hp:name?name ; hp:gender?gender.}
# Ground truth:
# SELECT?name?gender WHERE {?chief_warlock hp:name?name ; hp:gender?gender ; hp:job hp:Chief_warlock, hp:Wizengamot.}
#
# Question:
# What are the names of all the Hogwarts houses?
# Prediction:
# SELECT?name WHERE {?house hp:name?name. FILTER regex(str(?house), "Hogwarts") }
# Ground truth:
# SELECT?name WHERE {?house hp:name?name. FILTER regex(str(?house), "Hogwarts") }
#
# Question:
# What are the names of all the organisations affiliated with the British Ministry of Magic?
# Prediction:
# SELECT?name WHERE {?org hp:affiliation hp:British_ministry_of_magic ; hp:name?name. }
# Ground truth:
# SELECT?name WHERE {?org hp:affiliation hp:British_ministry_of_magic ; hp:name?name. }
#
# Question:
# Who are the individuals who have loyalty to the Order of the Phoenix?
# Prediction:
# SELECT?individual WHERE {?individual hp:loyalty hp:Order_of_the_phoenix ; a hp:Individual_.}
# Ground truth:
# SELECT?individual WHERE {?individual hp:loyalty hp:Order_of_the_phoenix ; a hp:Individual_.}
#
# Question:
# What organizations have been enemies of the Department of Magical Accidents and Catastrophes?
# Prediction:
# SELECT?enemy WHERE { hp:Department_of_magical_accidents_and_catastrophes hp:enemies?enemy. }
# Ground truth:
# SELECT?enemy WHERE { hp:Department_of_magical_accidents_and_catastrophes hp:enemies?enemy. }
#
# Question:
# What individuals are affiliated with Hogwarts School of Witchcraft and Wizardry and have been awarded the Order of Merlin?
# Prediction:
# SELECT DISTINCT?individual WHERE {?individual hp:loyalty hp:Hogwarts_school_of_witchcraft_and_wizardry, hp:Death_eaters ; hp:name?individualName.}
# Ground truth:
# SELECT?individual WHERE {?individual hp:loyalty hp:Hogwarts_school_of_witchcraft_and_wizardry, hp:Order_of_merlin. }
#
# Question:
# Who is the Chief Warlock of the Wizengamot in 1544 and what is his job?
# Prediction:
# SELECT?name?job WHERE { hp:Chief_warlock_of_the_wizengamot_in_1544 hp:name?name ; hp:job?job.}
# Ground truth:
# SELECT?name?job WHERE { hp:Chief_warlock_of_the_wizengamot_in_1544 hp:name?name. hp:Chief_warlock_of_the_wizengamot_in_1544 hp:job?job. }
#
# Question:
# What organizations is Hermione Granger loyal to?
# Prediction:
# SELECT?individual WHERE { hp:Hermione_granger hp:loyalty?individual. }
# Ground truth:
# SELECT?loyalty WHERE { hp:Hermione_granger hp:loyalty?loyalty. }
#
# Question:
# Who are the enemies of the Department of Magical Accidents and Catastrophes?
# Prediction:
# SELECT?enemy WHERE { hp:Department_of_magical_accidents_and_catastrophes hp:enemies?enemy. }
# Ground truth:
# SELECT?enemies WHERE { hp:Department_of_magical_accidents_and_catastrophes hp:enemies?enemies. }
#
# Question:
# Which organizations did Hermione Granger belong to, and what positions did she hold in those organizations?
# Prediction:
# SELECT?organization?position WHERE { hp:Hermione_granger hp:job?position. FILTER (?organization!= hp:Department_of_magical_law_enforcement, hp:Minister_for_magic)}
# Ground truth:
# SELECT?organization?position WHERE { hp:Hermione_granger hp:job?position.?organization hp:leader hp:Hermione_granger. FILTER(?organization!= hp:Hermione_granger) }
#
# Question:
# Which organizations had enemies in common, and what were those enemies?
# Prediction:
# SELECT DISTINCT?org1?org2?enemy WHERE {?org 1 hp:enemies?enemy. FILTER(?org2!=?org3) }
# Ground truth:
# SELECT DISTINCT?org1?org2?enemy WHERE {?org1 hp:enemies?enemy.?org2 hp:enemies?enemy. FILTER(?org1!=?org2) }
#
# Question:
# Which organizations had headquarters located at the British Ministry of Magic?
# Prediction:
# SELECT DISTINCT?org1?org2 WHERE {?organization hp:headquarters hp:British_ministry_of_magic. }
# Ground truth:
# SELECT?organization WHERE {?organization hp:headquarters hp:British_ministry_of_magic. }
#
# Question:
# What are the names of the individuals who are both members of the Order of the Phoenix and loyal to Hogwarts School of Witchcraft and Wizardry?
# Prediction:
# SELECT?name WHERE {?person hp:loyalty hp:Hogwarts_school_of_witchcraft_and_wizardry, hp:Death_eaters ; hp:name?name.?person a hp:Individual_. }
# Ground truth:
# SELECT?name WHERE {?person hp:loyalty hp:Hogwarts_school_of_witchcraft_and_wizardry, hp:Order_of_the_phoenix ; hp:name?name.?person a hp:Individual_. }
#
# Question:
# What is the name of the individual who was Chief Warlock of the Wizengamot in 1544 and what is their gender?
# Prediction:
# SELECT?name?gender WHERE { hp:Chief_warlock_of_the_wizengamot_in_1544 hp:name?name ; hp:gender?gender.?gender hp:loyalty?edgecombe.}
# Ground truth:
# SELECT?name?gender WHERE { hp:Chief_warlock_of_the_wizengamot_in_1544 hp:name?name ; hp:gender?gender. hp:Chief_warlock_of_the_wizengamot_in_1544 a hp:Individual_. }
#
# Question:
# What is the name of the wand that belonged to Cornelius Fudge and who were its masters?
# Prediction:
# SELECT?name?masters WHERE { hp:Cornelius_fudges_wand hp:name?name ; hp:masters?masters. }
# Ground truth:
# SELECT?wandName?masters WHERE { hp:Cornelius_fudges_wand hp:name?wandName ; hp:masters?masters. }
#
# Question:
# What are the names of the individuals who have the loyalty to the British Ministry of Magic and the Gryffindor house?
# Prediction:
# SELECT?name WHERE {?person hp:loyalty hp:British_ministry_of_magic, hp:Gryffindor ; hp:name?name.?person a hp:Individual_. }
# Ground truth:
# SELECT?name WHERE {?person hp:loyalty hp:British_ministry_of_magic, hp:Gryffindor ; hp:name?name.?person a hp:Individual_. }
#
# Question:
# What is the affiliation of the Astronomy Tower?
# Prediction:
# SELECT?affiliation WHERE { hp:Astronomy_tower hp:affiliation?affiliation. }
# Ground truth:
# SELECT?affiliation WHERE { hp:Astronomy_tower hp:affiliation?affiliation. }
#
# Question:
# Who is the leader of the Wizengamot?
# Prediction:
# SELECT?leader WHERE { hp:Wizengamot hp:leader?leader. }
# Ground truth:
# SELECT?leaderName WHERE { hp:Wizengamot hp:leader hp:Albus_dumbledore. hp:Albus_dumbledore hp:name?leaderName. }
#
# Question:
# What is the name of the organization founded by Harry Potter in 1997?
# Prediction:
# SELECT?organizationName WHERE { hp:Dumbledores_army hp:founder hp:Harry_potter ; hp:founded hp:1997.}
# Ground truth:
# SELECT?name WHERE { hp:Dumbledores_army hp:founder hp:Harry_potter. hp:Dumbledores_army hp:founded hp:1997. hp:Dumbledores_army hp:name?name. }
#
# Question:
# Who are the enemies of the Wizengamot?
# Prediction:
# SELECT?enemy WHERE { hp:Wizengamot hp:enemies?enemy. }
# Ground truth:
# SELECT?enemyName WHERE { hp:Wizengamot hp:enemies?enemy.?enemy hp:name?enemyName. }
#
# Question:
# Who owns Albus Dumbledore's wand?
# Prediction:
# SELECT?owners  WHERE { hp:Albus_dumbledores_wand hp:owners?owners.?owners hp:name?ownersName. }
# Ground truth:
# SELECT?ownerName WHERE { hp:Albus_dumbledores_wand hp:owners?owner.?owner hp:name?ownerName. }
#
# Question:
# Who is Albus Dumbledore's romance?
# Prediction:
# SELECT?romanceName WHERE { hp:Gellert_grindelwald hp:romances hp:Albus_dumbledore. hp:Hogwarts_school_of_witchcraft_and_wizengamot_wizardry hp:headquarters?headquarters. }
# Ground truth:
# SELECT?romanceName WHERE { hp:Gellert_grindelwald hp:romances hp:Albus_dumbledore. hp:Gellert_grindelwald hp:name?romanceName. }
#
# Question:
# Who is the professor of Defence Against the Dark Arts?
# Prediction:
# SELECT?professorName WHERE { hp:Defence_against_the_dark_arts hp:professor hp:Albus_dumbledores_father, hp:Hogwarts_school_of_witchcraft_and_wizardry. }
# Ground truth:
# SELECT?professorName WHERE { hp:Defence_against_the_dark_arts hp:professor?professor.?professor hp:name?professorName. }
#
# Question:
# What is the distinction of Phoenix?
# Prediction:
# SELECT?distinction WHERE { hp:Phoenix hp:distinction?distreme. }
# Ground truth:
# SELECT?distinction WHERE { hp:Phoenix hp:distinction?distinction. }
#
# Question:
# What is the name of the tower located at Hogwarts School of Witchcraft and Wizardry that is affiliated with the school?
# Prediction:
# SELECT?towerName WHERE { hp:Astronomy_tower hp:affiliation hp:Hogwarts_school_of_witchcraft_and_wizardry ; hp:towerName. }
# Ground truth:
# SELECT?towerName WHERE { hp:Astronomy_tower hp:affiliation hp:Hogwarts_school_of_witchcraft_and_wizardry. hp:Astronomy_tower hp:name?towerName. }
#
# Question:
# Who are the residents of Mould-on-the-wold?
# Prediction:
# SELECT?resident WHERE { hp:Mould_on_the_wold hp:residents?resident. }
# Ground truth:
# SELECT?residentName WHERE { hp:Mould_on_the_wold hp:residents?resident.?resident hp:name?residentName. }
#
# Question:
# Who is the prefect that is affiliated with Gryffindor and is the leader of the Head Boy or Girl?
# Prediction:
# SELECT?prefectName WHERE { hp:Head_boy_or_girl hp:affiliation hp:Gryffindor. hp:Prefect hp:leader hp:Half_boy, hp:Girl. }
# Ground truth:
# SELECT?prefectName WHERE { hp:Prefect hp:affiliation hp:Gryffindor. hp:Prefect hp:leader hp:Head_boy_or_girl. hp:Prefect hp:name?prefectName. }
#
# Question:
# Who subscribed to the Transfiguration Today newsletter?
# Prediction:
# SELECT?subscriberName WHERE { hp:Transfiguration_today hp:subscribers?subriber. }
# Ground truth:
# SELECT?subscriberName WHERE { hp:Transfiguration_today hp:subscribers?subscriber.?subscriber hp:name?subscriberName. }
#
# Question:
# What is the name of the organization founded in 1997 by Harry Potter with the intention of teaching Defence Against the Dark Arts?
# Prediction:
# SELECT?organizationName WHERE { hp:Dumbledores_army hp:founded hp:1997 ; hp:founder hp:Harry_potter. hp:Wizengamot hp:intentions hp:Defence_against_the_dark_arts.}
# Ground truth:
# SELECT?organizationName WHERE { hp:Dumbledores_army hp:founded hp:1997. hp:Dumbledores_army hp:founder hp:Harry_potter. hp:Dumbledores_army hp:intentions hp:Defence_against_the_dark_arts. hp:Dumbledores_army hp:name?organizationName. }
#
# Question:
# Who is the leader of the Wizengamot and who are its enemies?
# Prediction:
# SELECT?leader?enemy WHERE { hp:Wizengamot hp:leader?leader.?leader hp:name?leader ; hp:enemies?enemy. }
# Ground truth:
# SELECT?leaderName?enemyName WHERE { hp:Wizengamot hp:leader?leader.?leader hp:name?leaderName. hp:Wizengamot hp:enemies?enemy.?enemy hp:name?enemyName. }
#
# Question:
# What is the location of Mould on the Wold and who are its residents?
# Prediction:
# SELECT?location?residents WHERE { hp:Mould_on_the_wold hp:location?location. hp:Marietta_edgecombes_army hp:residents?resident. }
# Ground truth:
# SELECT?location?residents WHERE { hp:Mould_on_the_wold hp:location?location. hp:Mould_on_the_wold hp:residents?residents. }
#
# Question:
# Who is the leader of the Wizengamot and what is its affiliation and enemies?
# Prediction:
# SELECT?leader?affiliation?enemies WHERE { hp:Wizengamot hp:leader?leader. hp:Dumbledores_army hp:affiliation, hp:Minister_for_magic ; hp:enemies. }
# Ground truth:
# SELECT?leader?affiliation?enemies WHERE { hp:Wizengamot hp:leader?leader. hp:Wizengamot hp:affiliation?affiliation. hp:Wizengamot hp:enemies?enemies. }
#
# Question:
# What are the intentions of Dumbledore's Army and who founded it?
# Prediction:
# SELECT?intentions?founder WHERE { hp:Dumbledores_army hp:intentions ; hp:founder?founder.}
# Ground truth:
# SELECT?intentions?founder WHERE { hp:Dumbledores_army hp:intentions?intentions. hp:Dumbledores_army hp:founder?founder. }
#
# Question:
# Who is the romances of Gellert Grindelwald?
# Prediction:
# SELECT?romances WHERE { hp:Gellert_grindelwald hp:romances?romances. }
# Ground truth:
# SELECT?romances WHERE { hp:Gellert_grindelwald hp:romances?romances. }
#
# Question:
# What is the job of Harry Potter and what are his loyalties?
# Prediction:
# SELECT?job?loyalty WHERE { hp:Harry_potter hp:job?job. OPTIONAL {?individual a hp:Individual_. }
# Ground truth:
# SELECT?job?loyalty WHERE { hp:Harry_potter hp:job?job. hp:Harry_potter hp:loyalty?loyalty. }
#
# Question:
# Who was the leader of the Wizengamot and what is their affiliation?
# Prediction:
# SELECT?leader?affiliation  WHERE { hp:Wizengamot hp:leader?leader. hp:Dumbledores_army hp:affiliation?affiliation. }
# Ground truth:
# SELECT?leader?affiliation  WHERE { hp:Wizengamot hp:leader?leader. hp:Wizengamot hp:affiliation?affiliation. }
#
# Question:
# What is the name of the location where the Mould_on_the_wold is located?
# Prediction:
# SELECT?name WHERE { hp:Mould_on_the_wold hp:name?name. }
# Ground truth:
# SELECT?name WHERE { hp:Mould_on_the_wold hp:name?name. }
#
# Question:
# Who owns the Elder wand?
# Prediction:
# SELECT?owners  WHERE { hp:Elder_wand hp:owners?owners. }
# Ground truth:
# SELECT?owners  WHERE { hp:Elder_wand hp:owners?owners. }
#
# Question:
# Who founded Dumbledore's Army and what were their intentions?
# Prediction:
# SELECT?founder?intentions  WHERE { hp:Dumbledores_army hp:founder?founder. hp:Reverting_the_consequences_of_major_magical_mishaps hp:intentions?intention. }
# Ground truth:
# SELECT?founder?intentions  WHERE { hp:Dumbledores_army hp:founder?founder. hp:Dumbledores_army hp:intentions?intentions. }
#
# Question:
# What is the name of the person who romanced Gellert Grindelwald?
# Prediction:
# SELECT?romances  WHERE { hp:Gellert_grindelwald hp:romances? romances. }
# Ground truth:
# SELECT?romances  WHERE { hp:Gellert_grindelwald hp:romances?romances. }
#
# Question:
# Where is the Hogwarts castle located?
# Prediction:
# SELECT?location  WHERE { hp:Hogwarts_castle hp:location?location. }
# Ground truth:
# SELECT?location  WHERE { hp:Hogwarts_castle hp:location?location. }
#
# Question:
# Who are the residents of Mould_on_the_wold?
# Prediction:
# SELECT?resident WHERE { hp:Mould_on_the_wold hp:residents?resident. }
# Ground truth:
# SELECT?residents  WHERE { hp:Mould_on_the_wold hp:residents?residents. }
#
# Question:
# What is the name of the organization whose headquarters is at the British Ministry of Magic and who are their enemies?
# Prediction:
# SELECT?name?enemies  WHERE { hp:Wizengamot hp:name?name ; hp:affiliation hp:British_ministry_of_magic.}
# Ground truth:
# SELECT?name?enemies  WHERE { hp:Wizengamot hp:name?name. hp:Wizengamot hp:enemies?enemies. hp:Wizengamot hp:headquarters hp:British_ministry_of_magic. }
#
# Question:
# What is the name of the individual who has Albus Dumbledore's wand?
# Prediction:
# SELECT?name WHERE { hp:Albus_dumbledores_wand hp:owners?owners.?owners hp:name?name. }
# Ground truth:
# SELECT?name  WHERE { hp:Albus_dumbledores_wand hp:owners?owners.?owners hp:name?name. }
#
# Question:
# What is the name of the Hogwarts location in Great Britain with an affiliation to the Astronomy Tower?
# Prediction:
# SELECT?name WHERE { hp:Astronomy_tower hp:affiliation hp:Hogwarts_school_of_witchcraft_and_wizardry ; hp:name?name.}
# Ground truth:
# SELECT?name  WHERE { hp:Astronomy_tower hp:affiliation hp:Hogwarts_school_of_witchcraft_and_wizardry. hp:Astronomy_tower hp:location hp:Great_britain. hp:Astronomy_tower hp:name?name. }
#
# Question:
# ...
# Ground truth:
# SELECT?location?affiliation WHERE { hp:Minister_for_magics_office hp:location?location ; hp:affiliation?affiliation.}
#
# Question:
# What is the name of the wizarding organization responsible for dealing with improper use of magic, and who are their enemies?
# Prediction:
# SELECT?name?enemies WHERE { hp:Improper_use_of_magic_office hp:name?name ; hp:enemies?enemy.}
# Ground truth:
# SELECT?name?enemies WHERE { hp:Improper_use_of_magic_office hp:name?name ; hp:enemies?enemies.}
#
# Question:
# What is the name of the organization responsible for education, who do they lead, and what affiliations do they have?
# Prediction:
# SELECT?name?leader?affiliation WHERE { hp:Educational_office hp:name?name ; hp:leader?leader ; hp, hp:Minister_for_magic.}
# Ground truth:
# SELECT?name?leader?affiliation WHERE { hp:Educational_office hp:name?name ; hp:leader?leader ; hp:affiliation?affiliation.}
#
# Question:
# What is the name and species of Queenie Goldstein?
# Prediction:
# SELECT?name?species WHERE { hp:Queenie_goldstein hp:name?name ; hp:species?species.}
# Ground truth:
# SELECT?name?species WHERE { hp:Queenie_goldstein hp:name?name ; hp:species?species.}
#
# Question:
# What is the source URL for the Order of Merlin and for the Advisor to the Minister for Magic?
# Prediction:
# SELECT?order_source?advisor_source WHERE { hp:Order_of_merlin hp:source_url?order-source. hp:Advisor_to_the_minister_for_magic hp:enemies?enemy.}
# Ground truth:
# SELECT?order_source?advisor_source WHERE { hp:Order_of_merlin hp:source_url?order_source. hp:Advisor_to_the_minister_for_magic hp:source_url?advisor_source.}
#
# Question:
# What is the affiliation and location of the British Ministry of Magic headquarters?
# Prediction:
# SELECT?affiliation?location WHERE { hp:British_ministry_of_magic_headquarters hp:affiliation ; hp:location?location.}
# Ground truth:
# SELECT?affiliation?location WHERE { hp:British_ministry_of_magic_headquarters hp:affiliation?affiliation. hp:British_ministry_of_magic_headquarters hp:location?location.}
#
# Question:
# What is the source URL for information about Cornelius Fudge's wand?
# Prediction:
# SELECT?order_source WHERE { hp:Cornelius_fudges_wand hp:source_url?source_source.}
# Ground truth:
# SELECT?source_url WHERE { hp:Cornelius_fudges_wand hp:source_url?source_url.}
#
# Question:
# What is the name of the office held by Hermione Granger?
# Prediction:
# SELECT?office_name WHERE { hp:Hermione_granger hp:title?title.?job a hp:Individual_.}
# Ground truth:
# SELECT?office_name WHERE { hp:Hermione_granger hp:title?title.?title hp:name?office_name.}
#
# Question:
# Who is Queenie Goldstein and what is her blood status?
# Prediction:
# SELECT?name?blood_status WHERE { hp:Queenie_goldstein hp:name?name ; hp:blood? blood_status.}
# Ground truth:
# SELECT?name?blood_status WHERE { hp:Queenie_goldstein hp:name?name ; hp:blood?blood_status.}
#
# Question:
# What is the name of the Hogwarts house associated with the eagle?
# Prediction:
# SELECT?name WHERE { hp:Ravenclaw hp:name?name.}
# Ground truth:
# SELECT?house_name WHERE { hp:Ravenclaw hp:name?house_name.}
#
# Question:
# What is the source URL for information about the Order of Merlin?
# Prediction:
# SELECT?order_source WHERE { hp:Order_of_merlin hp:source_url?advisor_source.}
# Ground truth:
# SELECT?source_url WHERE { hp:Order_of_merlin hp:source_url?source_url.}
#
# Question:
# What is the name of the organization led by Albus Dumbledore that is enemies with the Order of the Phoenix and headquartered in the British Ministry of Magic?
# Prediction:
# SELECT?organizationName WHERE { hp:Wizengamot hp:leader hp:Albus_dumbledore ; hp:enemies hp:Order_of_the_phoenix.}
# Ground truth:
# SELECT?name WHERE { hp:Wizengamot hp:leader hp:Albus_dumbledore ; hp:enemies hp:Order_of_the_phoenix ; hp:headquarters hp:British_ministry_of_magic ; hp:name?name.}
#
# Question:
# What is the name of the location where the Council of Magical Law is located?
# Prediction:
# SELECT?name WHERE { hp:Council_of_magical_law hp:name?name.}
# Ground truth:
# SELECT?name WHERE { hp:Council_of_magical_law hp:name?name ; hp:affiliation hp:British_ministry_of_magic.}
#
# Question:
# Who are the enemies of the Wizengamot and what is its headquarters?
# Prediction:
# SELECT DISTINCT?org1?headquarters WHERE { hp:Wizengamot hp:enemies?enemy.?org2 hp:headquarters?headheadquarters. }
# Ground truth:
# SELECT?enemy?headquarters WHERE { hp:Wizengamot hp:enemies?enemy ; hp:headquarters?headquarters.}
#
# Question:
# Who is the professor of Defence Against the Dark Arts at Hogwarts School of Witchcraft and Wizardry?
# Prediction:
# SELECT?professorName WHERE { hp:Defence_against_the_dark_arts hp:professor hp:Hogwarts_school_of_witchcraft_and_wizardry. }
# Ground truth:
# SELECT?professor WHERE { hp:Defence_against_the_dark_arts hp:professor?professor.}
#
# Question:
# Who are the owners of the Elder Wand?
# Prediction:
# SELECT?owner WHERE { hp:Elder_wand hp:owners?owner.}
# Ground truth:
# SELECT?owner WHERE { hp:Elder_wand hp:owners?owner.}
#
# Question:
# What is the affiliation of the Phoenix and what is its distinction?
# Prediction:
# SELECT?affiliation?distinction WHERE { hp:Phoenix hp:affiliation?affiliation ; hp:distinction?distdistinction.}
# Ground truth:
# SELECT?affiliation?distinction WHERE { hp:Phoenix hp:affiliation?affiliation ; hp:distinction?distinction.}
#
# Question:
# Who founded Dumbledore's Army and what is its intention?
# Prediction:
# SELECT?founder?intention WHERE { hp:Dumbledores_army hp:founder?founder ; hp:intentions?intention.}
# Ground truth:
# SELECT?founder?intention WHERE { hp:Dumbledores_army hp:founder?founder ; hp:intentions?intention.}
#
# Question:
# What is the name of the individual who has the wand named 'Albus Dumbledore's Wand'?
# Prediction:
# SELECT?name WHERE { hp:Albus_dumbledores_wand hp:owners?owner.?owner hp:name?name.}
# Ground truth:
# SELECT?name WHERE { hp:Albus_dumbledores_wand hp:owners?owner.?owner hp:name?name.}
#
# Question:
# What is the name of the location affiliated with Mould on the Wold?
# Prediction:
# SELECT?name WHERE { hp:Mould_on_the_wold hp:location?location.?location hp:name?name.}
# Ground truth:
# SELECT?name WHERE { hp:Mould_on_the_wold hp:location?location.?location hp:name?name.}
#
# Question:
# What is the location of the Astronomy Tower?
# Prediction:
# SELECT?name WHERE { hp:Astronomy_tower hp:location?location.?location hp:name?name. FILTER(str(?location), str(hp:Great_britain)))}
# Ground truth:
# SELECT?locationName WHERE { hp:Astronomy_tower hp:location?location.?location hp:name?locationName.}
#
# Question:
# What is the name of the council of magical law affiliated with the British Ministry of Magic?
# Prediction:
# SELECT?councilName WHERE { hp:Council_of_magical_law hp:affiliation hp:British_ministry_magic ; hp:name?name.}
# Ground truth:
# SELECT?name WHERE { hp:Council_of_magical_law hp:affiliation hp:British_ministry_of_magic ; hp:name?name.}
#
# Question:
# Who are the residents of Mould-on-the-Wold?
# Prediction:
# SELECT?resident WHERE { hp:Mould_on_the_wold hp:residents?resident.}
# Ground truth:
# SELECT?residents WHERE { hp:Mould_on_the_wold hp:residents?residents.}
#
# Question:
# What is the affiliation of the Phoenix?
# Prediction:
# SELECT?affiliation WHERE { hp:Phoenix hp:affiliation?affiliator.}
# Ground truth:
# SELECT?affiliation WHERE { hp:Phoenix hp:affiliation?affiliation.}
#
# Question:
# Who is the Supreme Mugwump and leader of the International Confederation of Wizards?
# Prediction:
# SELECT?leader WHERE { hp:International_confederation_of_wizards hp:leader?leader. FILTER (CONTAINS(str(?leader), 'Supreme_mugwump'))}
# Ground truth:
# SELECT?leader WHERE { hp:International_confederation_of_wizards hp:leader?leader. FILTER (CONTAINS(str(?leader), 'Supreme_mugwump'))}
#
# Question:
# Who is the head boy or girl of the prefects?
# Prediction:
# SELECT?leader WHERE { hp:Prefect hp:leader hp:Head_boy_or_girl ; hp:name?leader.}
# Ground truth:
# SELECT?leader WHERE { hp:Prefect hp:leader hp:Head_boy_or_girl ; hp:name?leader.}
#
# Question:
# What is the name of the council that oversees magical laws in Great Britain?
# Prediction:
# SELECT?name WHERE { hp:Council_of_magical_law hp:name?name.}
# Ground truth:
# SELECT?name WHERE { hp:Council_of_magical_law hp:name?name.}
#
# Question:
# What is the name of the location where the Mould-on-the-wold is situated?
# Prediction:
# SELECT?name WHERE { hp:Mould_on_the_wold hp:name?name.}
# Ground truth:
# SELECT?name WHERE { hp:Mould_on_the_wold hp:name?name.}
#
# Question:
# What are the locations affiliated with Hogwarts School of Witchcraft and Wizardry?
# Prediction:
# SELECT?location WHERE { hp:Hogwarts_school_of_witchcraft_and_wizardry hp:location?location.}
# Ground truth:
# SELECT?location WHERE { hp:Hogwarts_school_of_witchcraft_and_wizardry hp:location?location.}
#
# Question:
# Who are the subscribers to Transfiguration Today?
# Prediction:
# SELECT?subscribers WHERE { hp:Transfiguration_today hp:scribers?scribers. }
# Ground truth:
# SELECT?subscribers WHERE { hp:Transfiguration_today hp:subscribers?subscribers.}
#
# Question:
# Who is the Supreme Mugwump of the International Confederation of Wizards?
# Prediction:
# SELECT?leader WHERE { hp:International_confederation_of_wizards hp:leader?leader.}
# Ground truth:
# SELECT?leader WHERE { hp:International_confederation_of_wizards hp:leader?leader.}
#
# Question:
# Who are the founders of Dumbledore's Army?
# Prediction:
# SELECT?founder WHERE { hp:Dumbledores_army hp:founder?founder.}
# Ground truth:
# SELECT?founder WHERE { hp:Dumbledores_army hp:founder?founder.}
#
# Question:
# What are the names of the characters in the Harry Potter universe who are Half-Bloods?
# Prediction:
# SELECT?character_name WHERE {?character a hp:Individual_; hp:name ; hp:blood hp:Half_blood.}
# Ground truth:
# SELECT?character_name WHERE {?character a hp:Individual_; hp:name?character_name ; hp:blood hp:Half_blood.}
#
# Question:
# What is the location of the Hogwarts Castle?
# Prediction:
# SELECT?locationName WHERE { hp:Hogwarts_castle hp:location?location.?location hp:name?location_name. FILTER(str(?location), str(hp:Great_britain)))}
# Ground truth:
# SELECT?location_name WHERE { hp:Hogwarts_castle hp:location?location ; hp:name?location_name. FILTER (strstarts(str(?location), str(hp:Great_britain)))}
#
# Question:
# Who is the owner of the Elder Wand?
# Prediction:
# SELECT?owner WHERE { hp:Elder_wand hp:owners?owner.}
# Ground truth:
# SELECT?owner_name WHERE { hp:Elder_wand hp:owners?owner.?owner hp:name?owner_name.}
#
# Question:
# What is the name of the organization that has Albus Dumbledore as its leader?
# Prediction:
# SELECT?name WHERE {?org hp:leader hp:Albus_dumbledore ; hp:name?name.}
# Ground truth:
# SELECT?organization_name WHERE {?organization hp:leader hp:Albus_dumbledore ; hp:name?organization_name.}
#
# Question:
# Which individuals in the Harry Potter universe are known to have owned the Elder Wand?
# Prediction:
# SELECT DISTINCT?individual_name WHERE { hp:Elder_wand hp:owners?owner.?owner a hp:Individual_.}
# Ground truth:
# SELECT?individual_name WHERE { hp:Elder_wand hp:owners?owner.?owner a hp:Individual_ ; hp:name?individual_name.}
#
# Question:
# Which organizations have Hogwarts School of Witchcraft and Wizardry as their affiliation?
# Prediction:
# SELECT?organization_name?affiliation WHERE {?organization hp:affiliation hp:Hogwarts_school_of_witchcraft_and_wizardry ; hp:name?organisation_name.}
# Ground truth:
# SELECT?organization_name WHERE {?organization hp:affiliation hp:Hogwarts_school_of_witchcraft_and_wizardry ; hp:name?organization_name.}
#
# Question:
# What is the name of the organization led by Albus Dumbledore that is an enemy of the British Ministry of Magic and has its headquarters at the British Ministry of Magic?
# Prediction:
# SELECT?name WHERE { hp:Wizengamot hp:leader hp:Albus_dumbledore ; hp:enemies hp:Order_of_the_phoenix.}
# Ground truth:
# SELECT?name WHERE { hp:Wizengamot hp:leader hp:Albus_dumbledore ; hp:name?name ; hp:enemies hp:Order_of_the_phoenix.}
#
# Question:
# What is the name of the Hogwarts castle owner?
# Prediction:
# SELECT?owner WHERE { hp:Hogwarts_castle hp:owner?owner.?owner hp:name?ownerName.}
# Ground truth:
# SELECT?ownerName WHERE { hp:Hogwarts_castle hp:owner?owner.?owner hp:name?ownerName.}
#
# Question:
# Who are the owners of the Elder wand?
# Prediction:
# SELECT?owners  WHERE { hp:Elder_wand hp:owners?owners.?owners hp:name?ownersName.}
# Ground truth:
# SELECT?ownerName WHERE { hp:Elder_wand hp:owners?owner.?owner hp:name?ownerName.}
#
# Question:
# Which individuals are loyal to Albus Dumbledore?
# Prediction:
# SELECT?individualName WHERE {?individual hp:loyalty hp:Albus_dumbledores_army.?individual a hp:IndividualName.}
# Ground truth:
# SELECT?individualName WHERE {?individual hp:loyalty hp:Albus_dumbledore.?individual hp:name?individualName.}
#
# Question:
# What is the name of the location where the British Ministry of Magic is headquartered?
# Prediction:
# SELECT?name WHERE { hp:Wizengamot hp:name?name ; hp:headquarters hp:British_ministry_of_magic.}
# Ground truth:
# SELECT?name WHERE { hp:Wizengamot hp:name?name ; hp:headquarters hp:British_ministry_of_magic.}
#
# Question:
# What is the name of the organization founded in 1997 with the intention of learning Defence Against the Dark Arts?
# Prediction:
# SELECT?name WHERE { hp:Dumbledores_army hp:founded hp:1997 ; hp:intentions hp:Defence_against_the_dark_arts.}
# Ground truth:
# SELECT?name WHERE { hp:Dumbledores_army hp:name?name ; hp:founded hp:1997 ; hp:intentions hp:Defence_against_the_dark_arts.}
#
# Question:
# What is the name of the location where Dumbledore's Army is headquartered?
# Prediction:
# SELECT?locationName WHERE { hp:Dumbledores_army hp:headquarters?location.?location hp:name?location_name.}
# Ground truth:
# SELECT?locationName WHERE { hp:Dumbledores_army hp:headquarters?location.?location hp:name?locationName.}
#
# Question:
# What is the name of the Hogwarts location in Scotland that is affiliated with Hogwarts School of Witchcraft and Wizardry?
# Prediction:
# SELECT?name WHERE { hp:Hogwarts_castle hp:location hp:Scotland ; hp:name?name ;hp:affiliation hp:British_ministry_of_magic, hp:Human.}
# Ground truth:
# SELECT?name WHERE { hp:Hogwarts_castle hp:location hp:Scotland ; hp:name?name ; hp:affiliation hp:Hogwarts_school_of_witchcraft_and_wizardry.}
#
# Question:
# Who is the head boy or girl of the Prefects?
# Prediction:
# SELECT?leader WHERE { hp:Prefect hp:leader hp:Head_boy_or_girl ; hp:name?leader.}
# Ground truth:
# SELECT?leader WHERE { hp:Prefect hp:leader hp:Head_boy_or_girl ; hp:name?leader.}
#
# Question:
# What is the name of the newspaper subscribed to by Albus Dumbledore?
# Prediction:
# SELECT?name WHERE { hp:Transfiguration_today hp:name?name ; hp:subscribers hp:Albus_dumbledore.}
# Ground truth:
# SELECT?name WHERE { hp:Transfiguration_today hp:name?name ; hp:subscribers hp:Albus_dumbledore.}
#
# Question:
# What is the name of the school where the Astronomy tower is located?
# Prediction:
# SELECT?schoolName WHERE { hp:Astronomy_tower hp:location?location.?location hp:name? schoolName. FILTER(CONTAINS(str(?location), 'Hogwarts'))}
# Ground truth:
# SELECT?schoolName WHERE { hp:Astronomy_tower hp:location?location.?location hp:name?schoolName. FILTER(CONTAINS(str(?location), 'Hogwarts'))}
#
# Question:
# What is the name of the council that belongs to the British Ministry of Magic?
# Prediction:
# SELECT?councilName WHERE { hp:Council_of_magical_law hp:affiliation hp:British_ministry_magic ; hp:name?Council_name.}
# Ground truth:
# SELECT?councilName WHERE { hp:Council_of_magical_law hp:affiliation hp:British_ministry_of_magic.hp:Council_of_magical_law hp:name?councilName.}
#
# Question:
# Which place in Great Britain is the location of Mould on the Wold?
# Prediction:
# SELECT?placeName WHERE { hp:Mould_on_the_wold hp:location?location.?location hp:name?place_name. FILTER(CONTAINS(str(?location), 'Great_britain'))}
# Ground truth:
# SELECT?placeName WHERE { hp:Mould_on_the_wold hp:location?location.?location hp:name?placeName. FILTER(CONTAINS(str(?location), 'Great_britain'))}
#
# Question:
# What is the name of the wand that belonged to Albus Dumbledore?
# Prediction:
# SELECT?name WHERE { hp:Albus_dumbledores_wand hp:name?name.}
# Ground truth:
# SELECT?wandName WHERE { hp:Albus_dumbledores_wand hp:name?wandName.}
# 0.0

# %%
#@title Default title text
test = Seq2SeqDataset(test_data)
count = 0
for index in range(len(test)):
  device = 'cuda'
  preds = model.generate(input_ids = torch.tensor(test[index]["input_ids"]).to(device).view(1,-1))
  #print(np.array(test[index]["labels"]))
  print("Question:")
  print(tokenizer.decode(np.array(test[index]["input_ids"]))[3:-4])
  print("Prediction:")
  print(tokenizer.decode(np.array(preds.cpu()[0]))[7:-4])
  print("Ground truth:")
  print(tokenizer.decode(np.array(test[index]["labels"]))[3:-4])
  print()
  #count+=1.0*(int(tokenizer.decode(np.array(preds.cpu()[0]))[5:-4]) == int(tokenizer.decode(np.array(test[index]["labels"]))[:-4]))
  #if index%10==0:
    #print(tokenizer.decode(np.array(preds.cpu()[0]))[5:-4],tokenizer.decode(np.array(test[index]["labels"]))[:-4])
count/len(test)
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1288: UserWarning: Using `max_length`'s default (1024) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Question:
# Who holds the position of the head of the Educational Office within the International Confederation of Wizards?
# Prediction:
# SELECT?position WHERE { hp:Educational_office hp:position?position.}
# Ground truth:
# SELECT?leader WHERE { hp:Educational_office hp:leader?leader.}
#
# Question:
# What is Queenie Goldstein's lineage in terms of blood status?
# Prediction:
# SELECT?name WHERE { hp:Queenie_goldstein hp:name?name.}
# Ground truth:
# SELECT?bloodStatus WHERE { hp:Queenie_goldstein hp:blood?bloodStatus.}
#
# Question:
# What is the name of the educational institution that houses the Astronomy Tower?
# Prediction:
# SELECT?name WHERE { hp:Astronomy_tower hp:house?house.?house hp:name?name.}
# Ground truth:
# SELECT?schoolName WHERE { hp:Astronomy_tower hp:location?location.?location hp:name?schoolName. FILTER(CONTAINS(str(?location), 'Hogwarts'))}
#
# Question:
# Where can the office of the Minister for Magic be found?
# Prediction:
# SELECT?office_name WHERE { hp:Minister_for_magics_office hp:location?location.?minister a hp:Individual_.}
# Ground truth:
# SELECT?location WHERE { hp:Minister_for_magics_office hp:location?location.}
#
# Question:
# What is the title and organization that the educational office belongs to within the wizarding community?
# Prediction:
# SELECT?title?affiliation WHERE { hp:Educational_office hp:title?title ; hp:affiliation hp:British_ministry_of_magic.}
# Ground truth:
# SELECT?name?affiliation WHERE { hp:Educational_office hp:name?name. hp:Educational_office hp:affiliation?affiliation.}
#
# Question:
# What organization does the Department of Magical Accidents and Catastrophes belong to?
# Prediction:
# SELECT?organization WHERE { hp:Department_of_magical_accidents_and_catastrophes hp:affiliation?affiliation.}
# Ground truth:
# SELECT?affiliation WHERE { hp:Department_of_magical_accidents_and_catastrophes hp:affiliation?affiliation.}
#
# Question:
# What is the lineage and type of creature of Queenie Goldstein?
# Prediction:
# SELECT?species?type WHERE { hp:Queenie_goldstein hp:species?species ; hp:type?type.}
# Ground truth:
# SELECT?blood_status?species WHERE { hp:Queenie_goldstein hp:blood?blood_status. hp:Queenie_goldstein hp:species?species.}
#
# Question:
# Where can the Astronomy Tower be found?
# Prediction:
# SELECT?location WHERE { hp:Astronomy_tower hp:location?location. }
# Ground truth:
# SELECT?locationName WHERE { hp:Astronomy_tower hp:location?location.?location hp:name?locationName.}
#
# Question:
# Who lives in Mould-on-the-Wold?
# Prediction:
# SELECT?individual WHERE { hp:Mould_on_the_wold hp:residents?individual. }
# Ground truth:
# SELECT?residents WHERE { hp:Mould_on_the_wold hp:residents?residents.}
#
# Question:
# Which characters in the Harry Potter universe have a mixed blood heritage known as Half-Bloods?
# Prediction:
# SELECT DISTINCT?character_name WHERE {?character a hp:Individual_; hp:blood hp:Half_blood.}
# Ground truth:
# SELECT?character_name WHERE {?character a hp:Individual_; hp:name?character_name ; hp:blood hp:Half_blood.}
#
# Question:
# Who held the position of Minister for Magic prior to Cornelius Fudge?
# Prediction:
# SELECT?position WHERE { hp:Cornelius_fudge hp:title?title.}
# Ground truth:
# SELECT?minister WHERE {?minister hp:title hp:Minister_for_magic ; hp:job hp:Minister_for_magic ; hp:loyalty hp:British_ministry_of_magic ; hp:species hp:Human. FILTER (?minister!= hp:Cornelius_fudge)}
#
# Question:
# What is the name of the group associated with Wizardkind that is led by the International Confederation of Wizards?
# Prediction:
# SELECT?name WHERE { hp:Wizardkind hp:leader hp:International_confederation_of_wizards ; hp:name?name.}
# Ground truth:
# SELECT?organizationName WHERE { hp:Educational_office hp:name?organizationName ; hp:leader hp:International_confederation_of_wizards ; hp:affiliation hp:Wizardkind.}
#
# Question:
# Who were the adversaries of the International Confederation of Wizards?
# Prediction:
# SELECT?enemy WHERE { hp:International_confederation_of_wizards hp:enemies?enemy.}
# Ground truth:
# SELECT?enemyName  WHERE { hp:International_confederation_of_wizards hp:enemies?enemy.?enemy hp:name?enemyName.}
#
# Question:
# Which people's worst fear was embodied by Tom Riddle in the form of a boggart?
# Prediction:
# SELECT?orgName?boggart WHERE {?org a hp:Individual_ ; hp:name?enemyName.}
# Ground truth:
# SELECT?individualName WHERE {?individual hp:boggart hp:Tom_riddle.?individual hp:name?individualName.}
#
# Question:
# What genders do people who belong to the British Ministry of Magic identify as?
# Prediction:
# SELECT?individualName WHERE {?individual hp:gender hp:Male ; hp:job hp:Department_of_magic.}
# Ground truth:
# SELECT DISTINCT?gender WHERE {?individual hp:loyalty hp:British_ministry_of_magic.?individual hp:gender?gender. }
#
# Question:
# What was the name given to the wand that was in the possession of Albus Dumbledore?
# Prediction:
# SELECT?name WHERE { hp:Albus_dumbledores_wand hp:owners?owner.?owner hp:name?name.}
# Ground truth:
# SELECT?wandName WHERE { hp:Albus_dumbledores_wand hp:name?wandName.}
#
# Question:
# What is the name of the location in Great Britain where Mould on the Wold is situated?
# Prediction:
# SELECT?name WHERE { hp:Mould_on_the_wold hp:name?name.}
# Ground truth:
# SELECT?placeName WHERE { hp:Mould_on_the_wold hp:location?location.?location hp:name?placeName. FILTER(CONTAINS(str(?location), 'Great_britain'))}
#
# Question:
# What is the name of the council affiliated with the British Ministry of Magic?
# Prediction:
# SELECT?council_name WHERE { hp:Council_of_magical_law hp:affiliation hp:British_ministry_magic ; hp:name?Council_name.}
# Ground truth:
# SELECT?councilName WHERE { hp:Council_of_magical_law hp:affiliation hp:British_ministry_of_magic.hp:Council_of_magical_law hp:name?councilName.}
#
# Question:
# In which school is the Astronomy tower situated?
# Prediction:
# SELECT?school_name WHERE { hp:Astronomy_tower hp:location?location.?location hp:name?schoolName. FILTER(CONTAINS(str(?location), 'Hogwarts'))}
# Ground truth:
# SELECT?schoolName WHERE { hp:Astronomy_tower hp:location?location.?location hp:name?schoolName. FILTER(CONTAINS(str(?location), 'Hogwarts'))}
#
# Question:
# Which newspaper did Albus Dumbledore subscribe to?
# Prediction:
# SELECT?magical_name WHERE { hp:Transfiguration_today hp:subscribers?subscriber. }
# Ground truth:
# SELECT?name WHERE { hp:Transfiguration_today hp:name?name ; hp:subscribers hp:Albus_dumbledore.}
#
# Question:
# Who currently holds the position of head boy or girl among the Prefects?
# Prediction:
# SELECT?position WHERE { hp:Prefect hp:title hp:Head_boy_or_girl. }
# Ground truth:
# SELECT?leader WHERE { hp:Prefect hp:leader hp:Head_boy_or_girl ; hp:name?leader.}
#
# Question:
# What is the name of the Scottish location affiliated with Hogwarts School of Witchcraft and Wizardry?
# Prediction:
# SELECT?name WHERE { hp:Mould_on_the_wold hp:location hp:Scotland ; hp:name?name.}
# Ground truth:
# SELECT?name WHERE { hp:Hogwarts_castle hp:location hp:Scotland ; hp:name?name ; hp:affiliation hp:Hogwarts_school_of_witchcraft_and_wizardry.}
#
# Question:
# What is the name of the headquarters where Dumbledore's Army is based?
# Prediction:
# SELECT?headquarters_name WHERE { hp:Dumbledores_army hp:headquarters?headheadquarters.?quarters a hp:Headquarters_of_the_phoenix.}
# Ground truth:
# SELECT?locationName WHERE { hp:Dumbledores_army hp:headquarters?location.?location hp:name?locationName.}
#
# Question:
# What is the name of the organization that was established in 1997 to learn Defence Against the Dark Arts?
# Prediction:
# SELECT?name WHERE { hp:Dumbledores_army hp:founded hp:1997 ; hp:intentions hp:Defence_against_the_dark_arts.}
# Ground truth:
# SELECT?name WHERE { hp:Dumbledores_army hp:name?name ; hp:founded hp:1997 ; hp:intentions hp:Defence_against_the_dark_arts.}
#
# Question:
# What is the name of the headquarters of the British Ministry of Magic?
# Prediction:
# SELECT?name  WHERE { hp:Wizengamot hp:name?name.}
# Ground truth:
# SELECT?name WHERE { hp:Wizengamot hp:name?name ; hp:headquarters hp:British_ministry_of_magic.}
#
# Question:
# Who are the individuals that demonstrate loyalty to Albus Dumbledore?
# Prediction:
# SELECT?individual WHERE {?individual hp:loyalty hp:Albus_dumbledore.}
# Ground truth:
# SELECT?individualName WHERE {?individual hp:loyalty hp:Albus_dumbledore.?individual hp:name?individualName.}
#
# Question:
# Which individuals possess the Elder wand?
# Prediction:
# SELECT?individual_name WHERE { hp:Elder_wand hp:owners?owner.?owner a hp:Individual_. }
# Ground truth:
# SELECT?ownerName WHERE { hp:Elder_wand hp:owners?owner.?owner hp:name?ownerName.}
#
# Question:
# Who is the owner of the Hogwarts castle?
# Prediction:
# SELECT?owner WHERE { hp:Hogwarts_castle hp:owner?owner. }
# Ground truth:
# SELECT?ownerName WHERE { hp:Hogwarts_castle hp:owner?owner.?owner hp:name?ownerName.}
#
# Question:
# What is the name of the organization, headed by Albus Dumbledore, that is hostile to the British Ministry of Magic and has its base of operations located within the Ministry itself?
# Prediction:
# SELECT?name WHERE { hp:Wizengamot hp:leader hp:Albus_dumbledore ; hp:enemies hp:Order_of_the_phoenix.}
# Ground truth:
# SELECT?name WHERE { hp:Wizengamot hp:leader hp:Albus_dumbledore ; hp:name?name ; hp:enemies hp:Order_of_the_phoenix.}
#
# Question:
# What are the organizations that are affiliated with Hogwarts School of Witchcraft and Wizardry?
# Prediction:
# SELECT?name WHERE {?organization hp:loyalty hp:Hogwarts_school_of_witchcraft_and_wizardry.?organisation hp:name?name.}
# Ground truth:
# SELECT?organization_name WHERE {?organization hp:affiliation hp:Hogwarts_school_of_witchcraft_and_wizardry ; hp:name?organization_name.}
# 0.0
